# %%
#copied from ideal_mhd_plots

import numpy as np
from matplotlib import pylab as plt
import athena_read

def rho_plot(file_name,plot_name):
  
    x,y,z,data = athena_read.vtk(file_name)

    #redefine x values to be average of adjacent outputs
    x_avg = []
    #print(data)
    for i in range(len(x)-1):
        x_avg.append((x[i]+x[i+1])/2)

   
    rho = data['rho'][0][0]
    axes[0][0].title.set_text('density')
    axes[0][0].plot(x_avg,rho,label = plot_name)
    #return minima to show time evolution
    return min(rho)

def velx_plot(file_name,plot_name):

    x,y,z,data = athena_read.vtk(file_name)

    #redefine x values to be average of adjacent outputs
    x_avg = []

    for i in range(len(x)-1):
        x_avg.append((x[i]+x[i+1])/2)


    vel = data['vel'][0][0][:,0]
    axes[1][0].plot(x_avg,vel,label = plot_name)
    axes[1][0].title.set_text('velocity x component')

def vely_plot(file_name,plot_name):

    x,y,z,data = athena_read.vtk(file_name)

    #redefine x values to be average of adjacent outputs
    x_avg = []

    for i in range(len(x)-1):
        x_avg.append((x[i]+x[i+1])/2)


    vel = data['vel'][0][0][:,1]
    axes[1][1].plot(x_avg,vel,label = plot_name)
    axes[1][1].title.set_text('velocity y component')

def velz_plot(file_name,plot_name):

    x,y,z,data = athena_read.vtk(file_name)

    #redefine x values to be average of adjacent outputs
    x_avg = []

    for i in range(len(x)-1):
        x_avg.append((x[i]+x[i+1])/2)


    vel = data['vel'][0][0][:,2]
    axes[1][2].plot(x_avg,vel,label = plot_name)
    axes[1][2].title.set_text('velocity z component')

    
    
def press_plot(file_name,plot_name):

    x,y,z,data = athena_read.vtk(file_name)

    #redefine x values to be average of adjacent outputs
    x_avg = []

    for i in range(len(x)-1):
        x_avg.append((x[i]+x[i+1])/2)


    press = data['press'][0][0]
    axes[0][1].title.set_text('pressure')
    axes[0][1].plot(x_avg,press,label = plot_name)

    
def by_plot(file_name,plot_name):

    x,y,z,data = athena_read.vtk(file_name)

    #redefine x values to be average of adjacent outputs
    x_avg = []

    for i in range(len(x)-1):
        x_avg.append((x[i]+x[i+1])/2)


    by = data['Bcc'][0][0][:,1]
    axes[2][1].title.set_text('magnetic y component')
    axes[2][1].plot(x_avg,by,label = plot_name)  
    

def bz_plot(file_name,plot_name):

    x,y,z,data = athena_read.vtk(file_name)

    #redefine x values to be average of adjacent outputs
    x_avg = []

    for i in range(len(x)-1):
        x_avg.append((x[i]+x[i+1])/2)


    bz = data['Bcc'][0][0][:,2]
    axes[2][2].title.set_text('magnetic z component')
    axes[2][2].plot(x_avg,bz,label = plot_name)  
    
    
fig1,axes = plt.subplots(3,3)
fig1.set_size_inches(15,10)
fig1.suptitle('Slow Magnetosonic 1-D wave, ideal and ambipolar diffusion')
#overlay ideal solutions

rho_plot('../ideal_mhd_1d/double_outputs_slow/LinWave.block0.out2.00470.vtk','ideal 50')
velx_plot('../ideal_mhd_1d/double_outputs_slow/LinWave.block0.out2.00470.vtk','ideal 50')
vely_plot('../ideal_mhd_1d/double_outputs_slow/LinWave.block0.out2.00470.vtk','ideal 50')
velz_plot('../ideal_mhd_1d/double_outputs_slow/LinWave.block0.out2.00470.vtk','ideal 50')
press_plot('../ideal_mhd_1d/double_outputs_slow/LinWave.block0.out2.00470.vtk','ideal 50')
by_plot('../ideal_mhd_1d/double_outputs_slow/LinWave.block0.out2.00470.vtk','ideal 50')
bz_plot('../ideal_mhd_1d/double_outputs_slow/LinWave.block0.out2.00470.vtk','ideal 50')

rho_plot('./slow/LinWave.block0.out2.00470.vtk','ad 50')
velx_plot('./slow/LinWave.block0.out2.00470.vtk','ad 50')
vely_plot('./slow/LinWave.block0.out2.00470.vtk','ad 50')
velz_plot('./slow/LinWave.block0.out2.00470.vtk','ad 50')
press_plot('./slow/LinWave.block0.out2.00470.vtk','ad 50')
by_plot('./slow/LinWave.block0.out2.00470.vtk','ad 50')
bz_plot('./slow/LinWave.block0.out2.00470.vtk','ad 50')


fig1.tight_layout()

fig1.show()

# %%
#Time evolution for the AD cases

import numpy as np
from matplotlib import pyplot as plt
#set up time array for referencing files in the format that athena outputs

lin_space = np.linspace(0,500,501)
file_list = []

for n in lin_space:
    n = str(int(n))
    while len(n) < 5:
        n = '0'+n
    file_list.append(n)


#set up max rho list to plot amplitude vs time later
vy_max_arr = []
vy_max_arr2 = []
vy_max_arr3 = []

#redefine vy_plot to be used for this specific subsection

def rho_plot(file_name,plot_name):
  
    x,y,z,data = athena_read.vtk(file_name)

    #redefine x values to be average of adjacent outputs
    x_avg = []
    #print(data)
    for i in range(len(x)-1):
        x_avg.append((x[i]+x[i+1])/2)

   
    rho = data['rho'][0][0]

    plt.plot(x_avg,rho,label = plot_name)
    #return maxima to show time evolution
    return max(rho)

def vely_plot(file_name,plot_name):

    x,y,z,data = athena_read.vtk(file_name)

    #redefine x values to be average of adjacent outputs
    x_avg = []

    for i in range(len(x)-1):
        x_avg.append((x[i]+x[i+1])/2)


    vel = data['vel'][0][0][:,1]
    plt.plot(x_avg,vel,label = plot_name)
    #return maxima to show time evolution
    return max(vel)

for t in file_list:
    vy_max_arr.append(vely_plot('./slow/LinWave.block0.out2.'+t+'.vtk',t+' slow'))
    vy_max_arr2.append(vely_plot('./alfvenic/LinWave.block0.out2.'+t+'.vtk',t+' alfvenic'))
    vy_max_arr3.append(vely_plot('./fast/LinWave.block0.out2.'+t+'.vtk',t+' fast'))
plt.show()
print(rho_max_arr)


plt.title('eta = .1 vy amplitude decay')
plt.plot(lin_space,vy_max_arr,label = 'slow', color = 'r')
plt.plot(lin_space,vy_max_arr2,label = 'alfvenic', color='k')
plt.plot(lin_space,vy_max_arr3,label = 'fast', color = 'b')
plt.legend()
plt.show()

#normalise to 5e-5, like bai and stone

#initial perturbation taken from analytical solutions for non-damped
vy_fast = 4.219867438701534e-05
vy_alf = 3.333333333333333e-05
vy_slow = 8.430990907875269e-05

vy_max_arr[:] = [i/vy_slow for i in vy_max_arr]
vy_max_arr2[:] = [i/vy_alf for i in vy_max_arr2]
vy_max_arr3[:] = [i/vy_fast for i in vy_max_arr3]

plt.title('eta = .01 density amplitude decay, normalised to initial vy')
plt.plot(lin_space,vy_max_arr,label = 'slow',color = 'r')
plt.plot(lin_space,vy_max_arr2,label = 'alfvenic',color = 'k')
plt.plot(lin_space,vy_max_arr3,label = 'fast',color = 'b')
plt.legend()
plt.show()
# Out:
# [1.000089406967163, 1.000084400177002, 1.0000834465026855, 1.0000818967819214, 1.0000746250152588, 1.0000741481781006, 1.0000720024108887, 1.0000680685043335, 1.0000649690628052, 1.000064492225647, 1.0000609159469604, 1.000057578086853, 1.0000572204589844, 1.0000547170639038, 1.0000513792037964, 1.0000503063201904, 1.000049352645874, 1.000045895576477, 1.000044345855713, 1.0000439882278442, 1.0000413656234741, 1.0000391006469727, 1.0000388622283936, 1.000037431716919, 1.0000348091125488, 1.000034213066101, 1.0000334978103638, 1.0000312328338623, 1.0000300407409668, 1.0000299215316772, 1.000028133392334, 1.0000265836715698, 1.0000264644622803, 1.0000253915786743, 1.0000237226486206, 1.0000232458114624, 1.0000227689743042, 1.00002121925354, 1.0000205039978027, 1.0000202655792236, 1.0000191926956177, 1.0000181198120117, 1.0000180006027222, 1.0000172853469849, 1.0000160932540894, 1.0000158548355103, 1.0000154972076416, 1.0000144243240356, 1.0000139474868774, 1.000013828277588, 1.00001299
# ...
