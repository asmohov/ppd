# %%
#For production of graphs

#Test streamlined methods on Am=10, eta = .1 case
import numpy as np
from eprime_y import az_avg_rho_vy
from eprime_y import az_avg_plotter
#already done if the appropriate file exists
az_avg_rho_vy('./ad_prof/const_am_big/point1_dev','am_point1_devel_sig_const',min_orbits = 0,max_orbits=8)
az_avg_plotter('am_point1_devel_sig_const.npz')
# Out:
# orbit number should be  range(0, 9)
# passing step  0
# (9, 512)
# rho calculation done
# passing step  0
# (9, 512)
# finished calculating az_avg for  am_point1_devel_sig_const
# (512, 9)

# %%
#Am = 10 short development run to see if still flat density
import numpy as np
from eprime_y import az_avg_rho_vy
from eprime_y import az_avg_plotter
#already done if the appropriate file exists
az_avg_rho_vy('./ad_prof/const_am_big/ten_dev','am_ten_devel_sig_const',min_orbits = 0,max_orbits=8)
az_avg_plotter('am_ten_devel_sig_const.npz')
# Out:
# orbit number should be  range(0, 9)
# passing step  0
# (9, 512)
# rho calculation done
# passing step  0
# (9, 512)
# finished calculating az_avg for  am_ten_devel_sig_const
# (512, 9)
