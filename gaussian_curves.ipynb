# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import cm
from matplotlib.colors import ListedColormap, LinearSegmentedColormap

viridis = cm.get_cmap('viridis', 101)

x_array = np.linspace(-4,4,100)

def gaussian(x,sigma):
    return np.exp(-(x**2)/(2*(sigma**2)))               
for sig in np.linspace(.25,10.25,101):
    y_array = []
    for equis in x_array:
        y_array.append(gaussian(equis,sig))

    if (sig-.25)%1== 0 :
        labl = 'sig='+str(sig)
        plt.plot(x_array,y_array,color=viridis(sig/5.25),label=labl)
    else:
        plt.plot(x_array,y_array,color=viridis(sig/5.25))
      
plt.legend(loc='upper right') 
plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import cm
from matplotlib.colors import ListedColormap, LinearSegmentedColormap

viridis = cm.get_cmap('viridis', 100)

x_array = np.linspace(-4,4,100)

def adj_gaussian(x,sigma):
    return .9*np.exp(-(x**2)/(2*(sigma**2)))+.1           
for sig in [.25,1,5,15]:
    y_array = []
    for equis in x_array:
        y_array.append(adj_gaussian(equis,sig))

    plt.plot(x_array,y_array,label=str(sig))

plt.ylim(0,1)      
plt.legend(loc='upper right') 
plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import cm
from matplotlib.colors import ListedColormap, LinearSegmentedColormap

viridis = cm.get_cmap('viridis', 100)

x_array = np.linspace(-4,4,100)

def adj_gaussian(x,sigma):
    return 1-.9*np.exp(-(x**2)/(2*(sigma**2)))           
for sig in [.25,1,5,15]:
    y_array = []
    for equis in x_array:
        y_array.append(adj_gaussian(equis,sig))

    plt.plot(x_array,y_array,label=str(sig))

plt.ylim(0,1)      
plt.legend(loc='upper right') 
plt.title('Inverted Gaussian $\eta_{ath}$ Profile') 
plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import cm
from matplotlib.colors import ListedColormap, LinearSegmentedColormap

#initialize figure
fig,ax = plt.subplots(1,2,sharey=True)
fig.set_size_inches(9,3)
plt.tight_layout()

#colorscale if needed
viridis = cm.get_cmap('viridis', 100)

x_array = np.linspace(-4,4,100)



def adj_gaussian(x,sigma):
    return .9*np.exp(-(x**2)/(2*(sigma**2)))+.1           
for sig in [.25,1,5]:
    y_array = []
    for equis in x_array:
        y_array.append(adj_gaussian(equis,sig))

    ax[0].plot(x_array,y_array,label=str(sig))
    ax[0].set_ylabel('$\\eta_{ath}$')
    ax[0].set_xlabel('$x/H$')
def adj_gaussian(x,sigma):
    return 1-.9*np.exp(-(x**2)/(2*(sigma**2)))           
for sig in [.25,1,5]:
    y_array = []
    for equis in x_array:
        y_array.append(adj_gaussian(equis,sig))

    ax[1].plot(x_array,y_array,label=str(sig))
    ax[1].set_xlabel('$x/H$')
    ax[1].legend()
ax[0].set_ylim(0,1)      
ax[1].set_ylim(0,1)
fig.savefig('gaussian_curves.jpeg')
