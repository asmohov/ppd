# %%
from eprime_y import eprime_y
import numpy as np

print('eprime is ',eprime_y('./ad_prof/const_am/HGB.out2.00040.athdf'))


eprime_tavg = []

for i in range(20,89):
    eprime_tavg.append(eprime_y('./ad_prof/const_am/HGB.out2.000'+str(i)+'.athdf'))
    print(i)
    print('current eprime is ',eprime_tavg[-1])
print('overall avg is ',np.average(eprime_tavg))
# Out:
# eprime is  0.0035417462803160964
# 20
# current eprime is  0.0016330888603296875
# 21
# current eprime is  0.0015213023331255785
# 22
# current eprime is  0.0015612622866470974
# 23
# current eprime is  0.0019569534684316216
# 24
# current eprime is  0.0022741161367483336
# 25
# current eprime is  0.0024750858908096506
# 26
# current eprime is  0.0028450915475982754
# 27
# current eprime is  0.002318346217126157
# 28
# current eprime is  0.0026233281216083656
# 29
# current eprime is  0.0029024490766368844
# 30
# current eprime is  0.002731888459953567
# 31
# current eprime is  0.002238411795431096
# 32
# current eprime is  0.002271688713969977
# 33
# current eprime is  0.0024402228194066048
# 34
# current eprime is  0.0030286378266987375
# 35
# current eprime is  0.003331736842820744
# 36
# current eprime is  0.003270988765872219
# 37
# current eprime is  0.0027012607737028817
# 38
# current eprime is  0.002319468840973453
# 39
# current eprime is  0.0029812630613428675
# 40
# current eprime is  0.0035417462803160964
# 41
# current eprime is  0.0031050607215541283
# 42
# current eprime is  0.003411472227160399
# 43
# current eprime is  0.003689314812797087
# 44
# current eprime is  0.0031992520163603155
# 45
# current eprime is  0.0032424002804644237
# 46
# current eprime is  0.0031020159932686527
# 47
# current eprime is  0.0032818160924351233
# 48
# current eprime is  0.003577017353459573
# 49
# current eprime is  0.003710501062308198
# 50
# current eprime is  0.003929960461970081
# 51
# current eprime is  0.003599362408743817
# 52
# current eprime is  0.004192208329615232
# 53
# current eprime is  0.004765207061539632
# 54
# current eprime is  0.0036543244343983728
# 55
# current eprime is  0.0032505136071232735
# 56
# current eprime is  0.0035537375589264103
# 57
# current eprime is  0.003762055488103325
# 58
# current eprime is  0.004427604686620953
# 59
# current eprime is  0.0040098559941092494
# 60
# current eprime is  0.00450876193799016
# 61
# current eprime is  0.004748524784371736
# 62
# current eprime is  0.003502461184375083
# 63
# current eprime is  0.003964792961295429
# 64
# current eprime is  0.005113247962109268
# 65
# current eprime is  0.005049046179857453
# 66
# current eprime is  0.0049948179366237225
# 67
# current eprime is  0.004704335574663255
# 68
# current eprime is  0.004579250857982253
# 69
# current eprime is  0.0047142537670656895
# 70
# current eprime is  0.0053251373436200835
# 71
# current eprime is  0.00618330277814805
# 72
# current eprime is  0.005606821230849681
# 73
# current eprime is  0.005799317139952989
# 74
# current eprime is  0.006138783150499501
# 75
# current eprime is  0.007101863263482314
# 76
# current eprime is  0.00724003323006219
# 77
# current eprime is  0.007710331034267159
# 78
# current eprime is  0.0069498054629516795
# 79
# current eprime is  0.007512912593073302
# 80
# current eprime is  0.008957145676975392
# 81
# current eprime is  0.008558687630401305
# 82
# current eprime is  0.007587223138733485
# 83
# current eprime is  0.00742565845924044
# 84
# current eprime is  0.007324542469322354
# 85
# current eprime is  0.007447102006430571
# 86
# current eprime is  0.007168378231788836
# 87
# current eprime is  0.007224426295818393
# 88
# current eprime is  0.007400467166606904
# overall avg is  0.004390919567522707
